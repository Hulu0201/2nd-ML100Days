# %% [markdown]
# ## 作業1：
# ### 請上 Kaggle, 在 Competitions 或 Dataset 中找一組競賽或資料並寫下：
# ### * 你選的這組資料為何重要
# #### 這是UCI Machine Learning Repository 廣泛使用前10名的資料集 透過分析，可以協助判斷乳癌為良性或是惡性
# ### * 資料從何而來 (tips: 譬如提供者是誰、以什麼方式蒐集)
# #### https://www.kaggle.com/uciml/breast-cancer-wisconsin-data 資料來源：UCI Machine Learning Repository，許多常見的資料也是由此網站提供，如iris。
# ### * 蒐集而來的資料型態為何
# #### 結構化資料，為CSV檔案 除了ID number & Diagnosis，其他欄位皆是數值
# ### * 這組資料想解決的問題如何評估
# #### 根據資料中Diagnosis診斷結果的欄位，分析細胞相關資料對於乳癌良惡性的影響 此為分類問題(malignant/benign)，可以依正確率及AUC作為評估
# ## 作業2：
# ### 想像你經營一個自由載客車隊，你希望能透過數據分析以提升業績，請你思考並描述你如何規劃整體的分析/解決方案：
# ### * 核心問題為何 (tips：如何定義 「提升業績 & 你的假設」)
# #### 假設 1)載客數 2)載客平均里程數，皆為影響提升業績的變數， 透過長期的資料來分析應增加載客數或是減少短程載客，會對於車隊的營收有較大的影響
# ### * 資料從何而來 (tips：哪些資料可能會對你想問的問題產生影響 & 資料如何蒐集)
# #### 透過司機每日回報來蒐集資料
# ### * 蒐集而來的資料型態為何
# #### 數值
# ### * 你要回答的問題，其如何評估 (tips：你的假設如何驗證)
# #### 利用迴歸分析來驗證

# %% [markdown]
# ## 練習時間
# #### 請寫一個函式用來計算 Mean Square Error
# $ MSE = \frac{1}{n}\sum_{i=1}^{n}{(Y_i - \hat{Y}_i)^2} $
#
# ### Hint: [如何取平方](https://googoodesign.gitbooks.io/-ezpython/unit-1.html)

# %%
import numpy as np #如R的library()
import matplotlib.pyplot as plt

# %%
w = 3
b = 0.5

x_lin = np.linspace(0, 100, 101) # 設0-100，有101個值

y = (x_lin + np.random.randn(101) * 5) * w + b  # random.randn()用來隨機建立資料

plt.plot(x_lin, y, 'b.', label = 'data points')
plt.title("Assume we have data points")
plt.legend(loc = 2)
plt.show()

# %%
y_hat = x_lin * w + b
plt.plot(x_lin, y, 'b.', label = 'data')
plt.plot(x_lin, y_hat, 'r-', label = 'prediction')
plt.title("Assume we have data points (And the prediction)")
plt.legend(loc = 2)
plt.show()

# %%
def mean_absolute_error(y, yp): #create method
    """
    計算 MAE
    Args:
        - y: 實際值
        - yp: 預測值
    Return:
        - mae: MAE
    """
    mae = MAE = sum(abs(y - yp)) / len(y)
    return mae

MAE = mean_absolute_error(y, y_hat)
print("The Mean absolute error is %.3f" % (MAE))
# Out:
# The Mean absolute error is 10.910

# %%
def mean_squared_error(y, y_hat):
    """
    計算 MSE
    Args:
        - y: 實際值
        - yp: 預測值
    Return:
        - mse: MSE
    """
    mse = MSE = sum((y - y_hat) ** 2)/ len(y)
    return mse

MSE = mean_squared_error(y, y_hat)
print("The Mean squared error is %.3f" % (MSE))
# Out:
# The Mean squared error is 175.121

# %%
# 執行 Function, 確認有沒有正常執行
MSE = mean_squared_error(y, y_hat)
MAE = mean_absolute_error(y, y_hat)
print("The Mean squared error is %.3f" % (MSE))
print("The Mean absolute error is %.3f" % (MAE))
# Out:
# The Mean squared error is 175.121
# The Mean absolute error is 10.910
